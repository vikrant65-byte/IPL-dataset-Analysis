# %%
import pyspark
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #SECTION-1

# %%
file_location = "/FileStore/tables/ipl_ball_by_ball.csv"  # File location and type
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df1 = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

# display(df1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# To change the data type I have used withcolumn() function

# %%
df1 = df1.withColumn("inning",df1["inning"].cast('integer')) \
         .withColumn("is_wicket",df1["is_wicket"].cast('integer'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# * All the other names are already updated with correct names as we have used header value as column name
# * Using withColumnRenamed() function To change Column name

# %%
New_df1 = df1.withColumnRenamed("ball","ball_num") \
             .withColumnRenamed("batsman","current_batsman")\
             .withColumnRenamed("fielder","fielder_name") \
             .withColumnRenamed("bowler","bowler_name") \
             .withColumnRenamed("overs","current_over")
New_df1.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- match_id: integer (nullable = true)
# -- inning: integer (nullable = true)
# -- current_over: integer (nullable = true)
# -- ball_num: integer (nullable = true)
# -- current_batsman: string (nullable = true)
# -- non_striker: string (nullable = true)
# -- bowler_name: string (nullable = true)
# -- batsman_runs: integer (nullable = true)
# -- extra_runs: integer (nullable = true)
# -- total_runs: integer (nullable = true)
# -- non_boundary: integer (nullable = true)
# -- is_wicket: integer (nullable = true)
# -- dismissal_kind: string (nullable = true)
# -- player_dismissed: string (nullable = true)
# -- fielder_name: string (nullable = true)
# -- extras_type: string (nullable = true)
# -- batting_team: string (nullable = true)
# -- bowling_team: string (nullable = true)
#
# </div>

# %% [markdown]
# Creating a view or table from our New_df1 Dataframe

# %%
per_ball_Table = "ipl_ball_by_ball_csv"
New_df1.createOrReplaceTempView("per_ball_Table")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Now Lets work on second Dataset which is Summary of IPL Matches

# %%
file_location2 = "/FileStore/tables/ipl_matches.csv"

df2 = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location2)

# display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>match_id</th><th>date</th><th>player_of_match</th><th>venue_id</th><th>neutral_venue</th><th>team1</th><th>team2</th><th>toss_winner</th><th>toss_decision</th><th>winner</th><th>result</th><th>result_margin</th><th>eliminator</th><th>method</th><th>umpire1</th><th>umpire2</th></tr></thead><tbody><tr><td>335982</td><td>18-04-2008</td><td>BB McCullum</td><td>35</td><td>0</td><td>Royal Challengers Bangalore</td><td>Kolkata Knight Riders</td><td>Royal Challengers Bangalore</td><td>field</td><td>Kolkata Knight Riders</td><td>runs</td><td>140</td><td>N</td><td>NA</td><td>Asad Rauf</td><td>RE Koertzen</td></tr><tr><td>335983</td><td>19-04-2008</td><td>MEK Hussey</td><td>31</td><td>0</td><td>Kings XI Punjab</td><td>Chennai Super Kings</td><td>Chennai Super Kings</td><td>bat</td><td>Chennai Super Kings</td><td>runs</td><td>33</td><td>N</td><td>NA</td><td>MR Benson</td><td>SL Shastri</td></tr><tr><td>335984</td><td>19-04-2008</td><td>MF Maharoof</td><td>27</td><td>0</td><td>Delhi Daredevils</td><td>Rajasthan Royals</td><td>Rajasthan Royals</td><td>bat</td><td>Delhi Daredevils</td><td>wickets</td><td>9</td><td>N</td><td>NA</td><td>Aleem Dar</td><td>GA Pratapkumar</td></tr><tr><td>335985</td><td>20-04-2008</td><td>MV Boucher</td><td>14</td><td>0</td><td>Mumbai Indians</td><td>Royal Challengers Bangalore</td><td>Mumbai Indians</td><td>bat</td><td>Royal Challengers Bangalore</td><td>wickets</td><td>5</td><td>N</td><td>NA</td><td>SJ Davis</td><td>DJ Harper</td></tr><tr><td>335986</td><td>20-04-2008</td><td>DJ Hussey</td><td>15</td><td>0</td><td>Kolkata Knight Riders</td><td>Deccan Chargers</td><td>Deccan Chargers</td><td>bat</td><td>Kolkata Knight Riders</td><td>wickets</td><td>5</td><td>N</td><td>NA</td><td>BF Bowden</td><td>K Hariharan</td></tr><tr><td>335987</td><td>21-04-2008</td><td>SR Watson</td><td>20</td><td>0</td><td>Rajasthan Royals</td><td>Kings XI Punjab</td><td>Kings XI Punjab</td><td>bat</td><td>Rajasthan Royals</td><td>wickets</td><td>6</td><td>N</td><td>NA</td><td>Aleem Dar</td><td>RB Tiffin</td></tr><tr><td>335988</td><td>22-04-2008</td><td>V Sehwag</td><td>22</td><td>0</td><td>Deccan Chargers</td><td>Delhi Daredevils</td><td>Deccan Chargers</td><td>bat</td><td>Delhi Daredevils</td><td>wickets</td><td>9</td><td>N</td><td>NA</td><td>IL Howell</td><td>AM Saheba</td></tr><tr><td>335989</td><td>23-04-2008</td><td>ML Hayden</td><td>29</td><td>0</td><td>Chennai Super Kings</td><td>Mumbai Indians</td><td>Mumbai Indians</td><td>field</td><td>Chennai Super Kings</td><td>runs</td><td>6</td><td>N</td><td>NA</td><td>DJ Harper</td><td>GA Pratapkumar</td></tr><tr><td>335990</td><td>24-04-2008</td><td>YK Pathan</td><td>22</td><td>0</td><td>Deccan Chargers</td><td>Rajasthan Royals</td><td>Rajasthan Royals</td><td>field</td><td>Rajasthan Royals</td><td>wickets</td><td>3</td><td>N</td><td>NA</td><td>Asad Rauf</td><td>MR Benson</td></tr><tr><td>335991</td><td>25-04-2008</td><td>KC Sangakkara</td><td>31</td><td>0</td><td>Kings XI Punjab</td><td>Mumbai Indians</td><td>Mumbai Indians</td><td>field</td><td>Kings XI Punjab</td><td>runs</td><td>66</td><td>N</td><td>NA</td><td>Aleem Dar</td><td>AM Saheba</td></tr><tr><td>335992</td><td>26-04-2008</td><td>SR Watson</td><td>35</td><td>0</td><td>Royal Challengers Bangalore</td><td>Rajasthan Royals</td><td>Rajasthan Royals</td><td>field</td><td>Rajasthan Royals</td><td>wickets</td><td>7</td><td>N</td><td>NA</td><td>MR Benson</td><td>IL Howell</td></tr><tr><td>335993</td><td>26-04-2008</td><td>JDP Oram</td><td>29</td><td>0</td><td>Chennai Super Kings</td><td>Kolkata Knight Riders</td><td>Kolkata Knight Riders</td><td>bat</td><td>Chennai Super Kings</td><td>wickets</td><td>9</td><td>N</td><td>NA</td><td>BF Bowden</td><td>AV Jayaprakash</td></tr><tr><td>335994</td><td>27-04-2008</td><td>AC Gilchrist</td><td>13</td><td>0</td><td>Mumbai Indians</td><td>Deccan Chargers</td><td>Deccan Chargers< ...

# %%
from pyspark.sql.functions import regexp_replace

New_df2 = df2.withColumn('method', regexp_replace('method','D/L','1'))   # Changing The Value of 'D/L' in method column by 1 for easier reference
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# To change the data type I have used withcolumn() function

# %%
New_df2 = New_df2.withColumn("date",New_df2["date"].cast('TimeStamp')) \
                 .withColumn("neutral_venue",New_df2["neutral_venue"].cast('Boolean'))  \
                 .withColumn("eliminator",New_df2["eliminator"].cast('Boolean')) \
                 .withColumn("result_margin",New_df2["result_margin"].cast('integer')) \
                 .withColumn("venue_id",New_df2["venue_id"].cast('integer'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# All the other names are already updated with correct names as we have used header value as column name
#
# Using withColumnRenamed() function To change Column name

# %%
New_df2 = New_df2.withColumnRenamed("result_margin","winning_margin") \
                 .withColumnRenamed("umpire1","umpire1_name")\
                 .withColumnRenamed("umpire2","umpire2_name") \
                 .withColumnRenamed("method","Dl_method_used")

New_df2.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- match_id: integer (nullable = true)
# -- date: timestamp (nullable = true)
# -- player_of_match: string (nullable = true)
# -- venue_id: integer (nullable = true)
# -- neutral_venue: boolean (nullable = true)
# -- team1: string (nullable = true)
# -- team2: string (nullable = true)
# -- toss_winner: string (nullable = true)
# -- toss_decision: string (nullable = true)
# -- winner: string (nullable = true)
# -- result: string (nullable = true)
# -- winning_margin: integer (nullable = true)
# -- eliminator: boolean (nullable = true)
# -- Dl_method_used: string (nullable = true)
# -- umpire1_name: string (nullable = true)
# -- umpire2_name: string (nullable = true)
#
# </div>

# %% [markdown]
# Lets work on The Third Dataframe

# %%
file_location3 = "/FileStore/tables/ipl_venue.csv"

df3 = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location3)

# display(df3)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>venue_id</th><th>venue</th><th>city</th></tr></thead><tbody><tr><td>1</td><td>Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium</td><td>Visakhapatnam</td></tr><tr><td>2</td><td>Sharjah Cricket Stadium</td><td>Sharjah</td></tr><tr><td>3</td><td>JSCA International Stadium Complex</td><td>Ranchi</td></tr><tr><td>4</td><td>Saurashtra Cricket Association Stadium</td><td>Rajkot</td></tr><tr><td>5</td><td>Shaheed Veer Narayan Singh International Stadium</td><td>Raipur</td></tr><tr><td>6</td><td>Maharashtra Cricket Association Stadium</td><td>Pune</td></tr><tr><td>7</td><td>Subrata Roy Sahara Stadium</td><td>Pune</td></tr><tr><td>8</td><td>St George's Park</td><td>Port Elizabeth</td></tr><tr><td>9</td><td>Vidarbha Cricket Association Stadium, Jamtha</td><td>Nagpur</td></tr><tr><td>12</td><td>Brabourne Stadium</td><td>Mumbai</td></tr><tr><td>13</td><td>Dr DY Patil Sports Academy</td><td>Mumbai</td></tr><tr><td>14</td><td>Wankhede Stadium</td><td>Mumbai</td></tr><tr><td>15</td><td>Eden Gardens</td><td>Kolkata</td></tr><tr><td>16</td><td>Nehru Stadium</td><td>Kochi</td></tr><tr><td>17</td><td>De Beers Diamond Oval</td><td>Kimberley</td></tr><tr><td>18</td><td>Green Park</td><td>Kanpur</td></tr><tr><td>19</td><td>New Wanderers Stadium</td><td>Johannesburg</td></tr><tr><td>20</td><td>Sawai Mansingh Stadium</td><td>Jaipur</td></tr><tr><td>21</td><td>Holkar Cricket Stadium</td><td>Indore</td></tr><tr><td>22</td><td>Rajiv Gandhi International Stadium, Uppal</td><td>Hyderabad</td></tr><tr><td>23</td><td>Buffalo Park</td><td>East London</td></tr><tr><td>24</td><td>Kingsmead</td><td>Durban</td></tr><tr><td>25</td><td>Dubai International Cricket Stadium</td><td>Dubai</td></tr><tr><td>26</td><td>Himachal Pradesh Cricket Association Stadium</td><td>Dharamsala</td></tr><tr><td>27</td><td>Feroz Shah Kotla</td><td>Delhi</td></tr><tr><td>28</td><td>Barabati Stadium</td><td>Cuttack</td></tr><tr><td>29</td><td>MA Chidambaram Stadium, Chepauk</td><td>Chennai</td></tr><tr><td>30</td><td>Punjab Cricket Association IS Bindra Stadium, Mohali</td><td>Chandigarh</td></tr><tr><td>31</td><td>Punjab Cricket Association Stadium, Mohali</td><td>Chandigarh</td></tr><tr><td>32</td><td>SuperSport Park</td><td>Centurion</td></tr><tr><td>33</td><td>Newlands</td><td>Cape Town</td></tr><tr><td>34</td><td>OUTsurance Oval</td><td>Bloemfontein</td></tr><tr><td>35</td><td>M.Chinnaswamy Stadium</td><td>Bengaluru</td></tr><tr><td>37</td><td>Sardar Patel Stadium, Motera</td><td>Ahmedabad</td></tr><tr><td>38</td><td>Sheikh Zayed Stadium</td><td>Abu Dhabi</td></tr></tbody></table></div>

# %% [markdown]
# Changing names for third dataframe

# %%
New_df3 = df3.withColumnRenamed("venue","stadium_name") \
             .withColumnRenamed("city","city_name")

New_df3.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- venue_id: integer (nullable = true)
# -- stadium_name: string (nullable = true)
# -- city_name: string (nullable = true)
#
# </div>

# %% [markdown]
# The table for third dataframe

# %%
ipl_venue_table = "ipl_venue_csv"
New_df3.createOrReplaceTempView("ipl_venue_table")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Lets Join the New_df2 and New_df3  dataframes using the common Id of venue_ID to make our analysis work easy

# %%
joined_summary_df = New_df2.join(New_df3, on=['venue_id'], how='inner')
# display(joined_summary_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>venue_id</th><th>match_id</th><th>date</th><th>player_of_match</th><th>neutral_venue</th><th>team1</th><th>team2</th><th>toss_winner</th><th>toss_decision</th><th>winner</th><th>result</th><th>winning_margin</th><th>eliminator</th><th>Dl_method_used</th><th>umpire1_name</th><th>umpire2_name</th><th>stadium_name</th><th>city_name</th></tr></thead><tbody><tr><td>35</td><td>335982</td><td>null</td><td>BB McCullum</td><td>false</td><td>Royal Challengers Bangalore</td><td>Kolkata Knight Riders</td><td>Royal Challengers Bangalore</td><td>field</td><td>Kolkata Knight Riders</td><td>runs</td><td>140</td><td>false</td><td>NA</td><td>Asad Rauf</td><td>RE Koertzen</td><td>M.Chinnaswamy Stadium</td><td>Bengaluru</td></tr><tr><td>31</td><td>335983</td><td>null</td><td>MEK Hussey</td><td>false</td><td>Kings XI Punjab</td><td>Chennai Super Kings</td><td>Chennai Super Kings</td><td>bat</td><td>Chennai Super Kings</td><td>runs</td><td>33</td><td>false</td><td>NA</td><td>MR Benson</td><td>SL Shastri</td><td>Punjab Cricket Association Stadium, Mohali</td><td>Chandigarh</td></tr><tr><td>27</td><td>335984</td><td>null</td><td>MF Maharoof</td><td>false</td><td>Delhi Daredevils</td><td>Rajasthan Royals</td><td>Rajasthan Royals</td><td>bat</td><td>Delhi Daredevils</td><td>wickets</td><td>9</td><td>false</td><td>NA</td><td>Aleem Dar</td><td>GA Pratapkumar</td><td>Feroz Shah Kotla</td><td>Delhi</td></tr><tr><td>14</td><td>335985</td><td>null</td><td>MV Boucher</td><td>false</td><td>Mumbai Indians</td><td>Royal Challengers Bangalore</td><td>Mumbai Indians</td><td>bat</td><td>Royal Challengers Bangalore</td><td>wickets</td><td>5</td><td>false</td><td>NA</td><td>SJ Davis</td><td>DJ Harper</td><td>Wankhede Stadium</td><td>Mumbai</td></tr><tr><td>15</td><td>335986</td><td>null</td><td>DJ Hussey</td><td>false</td><td>Kolkata Knight Riders</td><td>Deccan Chargers</td><td>Deccan Chargers</td><td>bat</td><td>Kolkata Knight Riders</td><td>wickets</td><td>5</td><td>false</td><td>NA</td><td>BF Bowden</td><td>K Hariharan</td><td>Eden Gardens</td><td>Kolkata</td></tr><tr><td>20</td><td>335987</td><td>null</td><td>SR Watson</td><td>false</td><td>Rajasthan Royals</td><td>Kings XI Punjab</td><td>Kings XI Punjab</td><td>bat</td><td>Rajasthan Royals</td><td>wickets</td><td>6</td><td>false</td><td>NA</td><td>Aleem Dar</td><td>RB Tiffin</td><td>Sawai Mansingh Stadium</td><td>Jaipur</td></tr><tr><td>22</td><td>335988</td><td>null</td><td>V Sehwag</td><td>false</td><td>Deccan Chargers</td><td>Delhi Daredevils</td><td>Deccan Chargers</td><td>bat</td><td>Delhi Daredevils</td><td>wickets</td><td>9</td><td>false</td><td>NA</td><td>IL Howell</td><td>AM Saheba</td><td>Rajiv Gandhi International Stadium, Uppal</td><td>Hyderabad</td></tr><tr><td>29</td><td>335989</td><td>null</td><td>ML Hayden</td><td>false</td><td>Chennai Super Kings</td><td>Mumbai Indians</td><td>Mumbai Indians</td><td>field</td><td>Chennai Super Kings</td><td>runs</td><td>6</td><td>false</td><td>NA</td><td>DJ Harper</td><td>GA Pratapkumar</td><td>MA Chidambaram Stadium, Chepauk</td><td>Chennai</td></tr><tr><td>22</td><td>335990</td><td>null</td><td>YK Pathan</td><td>false</td><td>Deccan Chargers</td><td>Rajasthan Royals</td><td>Rajasthan Royals</td><td>field</td><td>Rajasthan Royals</td><td>wickets</td><td>3</td><td>false</td><td>NA</td><td>Asad Rauf</td><td>MR Benson</td><td>Rajiv Gandhi International Stadium, Uppal</td><td>Hyderabad</td></tr><tr><td>31</td><td>335991</td><td>null</td><td>KC Sangakkara</td><td>false</td><td>Kings XI Punjab</td><td>Mumbai Indians</td><td>Mumbai Indians</td><td>field</td><td>Kings XI Punjab</td><td>runs</td><td>66</td><td>false</td><td>NA</td><td>Aleem Dar</td><td>AM Saheba</td><td>Punjab Cricket Association Stadium, Mohali</td><td>Chandigarh</td></tr><tr><td>35</td><td>335992</td><td>null</td><td>SR Watson</td><td>false</td><td>Royal Challengers Bangalore</td><td ...

# %% [markdown]
# Lets create a new dataframe with count of umpire1_name and umpire2_name columns

# %% [markdown]
# We will use this dataframe by converting it into Table for performing SQl query for umpires count

# %%
import pandas as pd

umpire_column_1 = joined_summary_df.select('umpire1_name')
umpire_column_2 = joined_summary_df.select('umpire2_name')
  
umpire_name_union = umpire_column_1.union(umpire_column_2) # Creating new dataframe with union of these two dataframes

umpire_name_union.toPandas().to_csv('umpire_name_union.csv') # Converting  umpire_name_union to csv file

umpire_union_table = "umpire_name_union_csv"

umpire_name_union.createOrReplaceTempView("umpire_name_union_table") # Table using the  umpire_name_union_csv
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Created a new CSV file for joined_summary_df to create its Table later

# %%
joined_summary_df.toPandas().to_csv('mycsv.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Lets create a table for joined_summary_df which we will use to run query for venue details in more optmized way

# %%
venue_summary_table =  "mycsv_csv"
joined_summary_df.createOrReplaceTempView("venue_summary_table")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Lets do the same above steps to join all the three datasets using join on match_id and create its table

# %%
Entire_dataset = New_df1.join(joined_summary_df, on=['match_id'], how='inner')
Entire_dataset.toPandas().to_csv('all_data.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Entire_dataset_table =  "all_data_csv"
Entire_dataset.createOrReplaceTempView("Entire_dataset_table")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #SECTION-2

# %% [markdown]
# ***Lets Start with the Queries which we have to solve for our data analysis work***

# %% [markdown]
# 1)  Write a query to find the highest extra runs given by a team in a match.

# %%
sqlContext.sql('select batting_team,match_id,bowling_team,SUM(extra_runs) FROM Entire_dataset_table \
GROUP BY match_id,bowling_team,batting_team ORDER BY SUM(extra_runs) DESC Limit 1').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------+---------------+---------------+
#         batting_team|match_id|   bowling_team|sum(extra_runs)|
# +--------------------+--------+---------------+---------------+
# Kolkata Knight Ri...|  335986|Deccan Chargers|             28|
# +--------------------+--------+---------------+---------------+
#
# </div>

# %% [markdown]
# 2) Write a query to find the Leading wicket taker in the IPL?
# Note: A wicket won't be accounted for the bowler, if the dismissal is run out,
# obstructing the field.

# %%
sqlContext.sql('select bowler_name,SUM(is_wicket)AS Total_wickets FROM Entire_dataset_table where Not dismissal_kind = "run out" "obstructing the field" \
GROUP BY bowler_name ORDER BY SUM(is_wicket) DESC Limit 1').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-------------+
# bowler_name|Total_wickets|
# +-----------+-------------+
#  SL Malinga|          188|
# +-----------+-------------+
#
# </div>

# %% [markdown]
# 3)    Write a query to return a report for highest run scorer in matches which were
# affected by Duckworth-Lewis’s method (D/L method).
#
# Here I have written an query to return top 3 batsmen who scored highest runs in mathces affected by D/L Rule.
#
#
# We can simple use limit 1 to get batsmen with most runs

# %%
sqlContext.sql(' select current_batsman As Player_name,SUM(batsman_runs) AS Total_runs FROM Entire_dataset_table \
where Dl_method_used = 1 GROUP BY current_batsman ORDER BY SUM(batsman_runs) DESC limit 3').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+----------+
# Player_name|Total_runs|
# +-----------+----------+
#    CH Gayle|       252|
#   DA Warner|       192|
#     V Kohli|       172|
# +-----------+----------+
#
# </div>

# %% [markdown]
# 4) Write a query to return a report for highest strike rate by a batsman in
# powerplay (1-6 overs)
# Note: strike rate = (Total Runs scored/Total balls faced by player) *100, Make
# sure that balls faced by player should be legal delivery (not wide balls or no
# balls)

# %%
sqlContext.sql('select  current_batsman As Player_name ,Round((sum(batsman_runs)/count(batsman_runs))*100,2) as Strike_rate \
from Entire_dataset_table  where current_over between 1 and 6 AND  extras_type = "NA" \
GROUP BY current_batsman ORDER BY Strike_rate DESC Limit 1' ).show()   # Extra Runs Like Wide ball, No ball, Byes, Leg-byes & penalty are not included into batsman runs
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-----------+
# Player_name|Strike_rate|
# +-----------+-----------+
#   CH Morris|     271.43|
# +-----------+-----------+
#
# </div>

# %% [markdown]
# 5) Write a query to return a report for highest extra runs in a venue (stadium,
# city).

# %%
sqlContext.sql(' select city_name,stadium_name,SUM(extra_runs) AS Total_Extra_runs FROM Entire_dataset_table \
GROUP BY stadium_name,city_name ORDER BY SUM(extra_runs) DESC Limit 1').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+--------------------+----------------+
# city_name|        stadium_name|Total_Extra_runs|
# +---------+--------------------+----------------+
# Bengaluru|M.Chinnaswamy Sta...|            1355|
# +---------+--------------------+----------------+
#
# </div>

# %% [markdown]
# 6)  Write a query to return a report for the cricketers with the most number of
# players of the match award in neutral venues.

# %%
sqlContext.sql('select player_of_match AS Player_name, COUNT(player_of_match) AS MOM_Awards from venue_summary_table \
where neutral_venue = true GROUP BY player_of_match  ORDER BY COUNT(player_of_match)  DESC Limit 5').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+----------+
#   Player_name|MOM_Awards|
# +-------------+----------+
#     YK Pathan|         3|
#     JH Kallis|         3|
#     JP Duminy|         3|
#    GJ Maxwell|         3|
# KC Sangakkara|         2|
# +-------------+----------+
#
# </div>

# %% [markdown]
# 7 )  Write a query to get a list of top 10 players with the highest batting average
# Note: Batting average is the total number of runs scored divided by the
# number of times they have been out (Make sure to include run outs (on nonstriker end) as valid out while calculating average).

# %%
sqlContext.sql('select  current_batsman AS Player_name, Round((sum(batsman_runs)/ sum(is_wicket)), 2 ) as Batting_average \
from Entire_dataset_table  GROUP BY current_batsman ORDER BY Batting_average DESC Limit 10' ).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------+---------------+
#    Player_name|Batting_average|
# +--------------+---------------+
#  Iqbal Abdulla|           88.0|
#     RD Gaikwad|           68.0|
#     MN van Wyk|          55.67|
# PD Collingwood|          50.75|
#        HM Amla|          44.38|
#    LH Ferguson|           44.0|
#       KL Rahul|          42.69|
# AB de Villiers|          42.54|
#      DA Warner|           41.7|
#      JP Duminy|          41.41|
# +--------------+---------------+
#
# </div>

# %% [markdown]
# 8)  Write a query to find out who has officiated (as an umpire) the most number of
# matches in IPL

# %%
sqlContext.sql('select umpire1_name AS Umpire_name, Count(umpire1_name) as Total_matches from umpire_name_union_table \
GROUP BY umpire1_name ORDER BY COUNT(umpire1_name) DESC Limit 1').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-------------+
# Umpire_name|Total_matches|
# +-----------+-------------+
#      S Ravi|          121|
# +-----------+-------------+
#
# </div>

# %% [markdown]
# 9)   Find venue details of the match where V Kohli scored his highest individual runs
# in IPL.

# %%
sqlContext.sql(' select stadium_name,city_name,SUM(batsman_runs) FROM Entire_dataset_table where current_batsman = "V Kohli" \
GROUP BY stadium_name,city_name ORDER BY SUM(batsman_runs) DESC limit 1').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+---------+-----------------+
#         stadium_name|city_name|sum(batsman_runs)|
# +--------------------+---------+-----------------+
# M.Chinnaswamy Sta...|Bengaluru|             2346|
# +--------------------+---------+-----------------+
#
# </div>

# %% [markdown]
# #Section - 3#

# %% [markdown]
# To create a SQLlite database import all the required python libraries

# %%
import sqlite3 as sqlt

import pandas as pd

Entire_IPL_Data = pd.read_csv('all_data.csv')

#display(Entire_IPL_Data)

try:
  conn = sqlt.connect('Entire_dataset_table.db')
except:
  pass

Entire_IPL_Data.to_sql('Entire_dataset_table', conn)

Entire_IPL_Data1 = pd.read_sql('SELECT * FROM Entire_dataset_table', conn)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (30) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Unnamed: 0</th><th>match_id</th><th>inning</th><th>current_over</th><th>ball_num</th><th>current_batsman</th><th>non_striker</th><th>bowler_name</th><th>batsman_runs</th><th>extra_runs</th><th>total_runs</th><th>non_boundary</th><th>is_wicket</th><th>dismissal_kind</th><th>player_dismissed</th><th>fielder_name</th><th>extras_type</th><th>batting_team</th><th>bowling_team</th><th>venue_id</th><th>date</th><th>player_of_match</th><th>neutral_venue</th><th>team1</th><th>team2</th><th>toss_winner</th><th>toss_decision</th><th>winner</th><th>result</th><th>winning_margin</th><th>eliminator</th><th>Dl_method_used</th><th>umpire1_name</th><th>umpire2_name</th><th>stadium_name</th><th>city_name</th></tr></thead><tbody><tr><td>0</td><td>419157</td><td>2</td><td>16</td><td>4</td><td>V Kohli</td><td>R Vinay Kumar</td><td>CRD Fernando</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>Royal Challengers Bangalore</td><td>Mumbai Indians</td><td>35</td><td>null</td><td>R McLaren</td><td>false</td><td>Royal Challengers Bangalore</td><td>Mumbai Indians</td><td>Royal Challengers Bangalore</td><td>field</td><td>Mumbai Indians</td><td>runs</td><td>57.0</td><td>false</td><td>null</td><td>HDPK Dharmasena</td><td>SJA Taufel</td><td>M.Chinnaswamy Stadium</td><td>Bengaluru</td></tr><tr><td>1</td><td>419157</td><td>2</td><td>16</td><td>5</td><td>V Kohli</td><td>R Vinay Kumar</td><td>CRD Fernando</td><td>1</td><td>0</td><td>1</td><td>0</td><td>0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>Royal Challengers Bangalore</td><td>Mumbai Indians</td><td>35</td><td>null</td><td>R McLaren</td><td>false</td><td>Royal Challengers Bangalore</td><td>Mumbai Indians</td><td>Royal Challengers Bangalore</td><td>field</td><td>Mumbai Indians</td><td>runs</td><td>57.0</td><td>false</td><td>null</td><td>HDPK Dharmasena</td><td>SJA Taufel</td><td>M.Chinnaswamy Stadium</td><td>Bengaluru</td></tr><tr><td>2</td><td>419157</td><td>2</td><td>16</td><td>6</td><td>R Vinay Kumar</td><td>V Kohli</td><td>CRD Fernando</td><td>1</td><td>0</td><td>1</td><td>0</td><td>0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>Royal Challengers Bangalore</td><td>Mumbai Indians</td><td>35</td><td>null</td><td>R McLaren</td><td>false</td><td>Royal Challengers Bangalore</td><td>Mumbai Indians</td><td>Royal Challengers Bangalore</td><td>field</td><td>Mumbai Indians</td><td>runs</td><td>57.0</td><td>false</td><td>null</td><td>HDPK Dharmasena</td><td>SJA Taufel</td><td>M.Chinnaswamy Stadium</td><td>Bengaluru</td></tr><tr><td>3</td><td>419157</td><td>2</td><td>17</td><td>1</td><td>R Vinay Kumar</td><td>V Kohli</td><td>R McLaren</td><td>1</td><td>0</td><td>1</td><td>0</td><td>0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>Royal Challengers Bangalore</td><td>Mumbai Indians</td><td>35</td><td>null</td><td>R McLaren</td><td>false</td><td>Royal Challengers Bangalore</td><td>Mumbai Indians</td><td>Royal Challengers Bangalore</td><td>field</td><td>Mumbai Indians</td><td>runs</td><td>57.0</td><td>false</td><td>null</td><td>HDPK Dharmasena</td><td>SJA Taufel</td><td>M.Chinnaswamy Stadium</td><td>Bengaluru</td></tr><tr><td>4</td><td>419157</td><td>2</td><td>17</td><td>2</td><td>V Kohli</td><td>R Vinay Kumar</td><td>R McLaren</td><td>1</td><td>0</td><td>1</td><td>0</td><td>0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>Royal Challengers Bangalore</td><td>Mumbai Indians</td><td>35</td><td>null</td><td>R McLaren</td><td>false</td><td>Royal Challengers Bangalore</td><td>Mumbai Indians</td><td>Royal Challengers Bangalore</td><td>field</td><td>Mumbai Indians</td><td>runs</td><td>57.0</td><td>false</td><td>null</td><td>HDPK Dharmasena</td><td>SJA Taufel</td><td>M.Chinnaswamy Stadium</td><td>Bengaluru</td></tr><tr><td>5</td><td>419157</td><td>2</td><td>17</td><td>3</td><td>R Vinay Kumar</td> ...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ValueError</span>                                Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-724917664544768&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">     11</span>   <span class="ansi-green-fg">pass</span>
# <span class="ansi-green-intense-fg ansi-bold">     12</span>
# <span class="ansi-green-fg">---&gt; 13</span><span class="ansi-red-fg"> </span>Entire_IPL_Data<span class="ansi-blue-fg">.</span>to_sql<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;Entire_dataset_table&#39;</span><span class="ansi-blue-fg">,</span> conn<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">     14</span>
# <span class="ansi-green-intense-fg ansi-bold">     15</span> Entire_IPL_Data1 <span class="ansi-blue-fg">=</span> pd<span class="ansi-blue-fg">.</span>read_sql<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;SELECT * FROM Entire_dataset_table&#39;</span><span class="ansi-blue-fg">,</span> conn<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/pandas/core/generic.py</span> in <span class="ansi-cyan-fg">to_sql</span><span class="ansi-blue-fg">(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)</span>
# <span class="ansi-green-intense-fg ansi-bold">   2603</span>         <span class="ansi-green-fg">from</span> pandas<span class="ansi-blue-fg">.</span>io <span class="ansi-green-fg">import</span> sql
# <span class="ansi-green-intense-fg ansi-bold">   2604</span>
# <span class="ansi-green-fg">-&gt; 2605</span><span class="ansi-red-fg">         sql.to_sql(
# </span><span class="ansi-green-intense-fg ansi-bold">   2606</span>             self<span class="ansi-blue-fg">,</span>
# <span class="ansi-green-intense-fg ansi-bold">   2607</span>             name<span class="ansi-blue-fg">,</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/pandas/io/sql.py</span> in <span class="ansi-cyan-fg">to_sql</span><span class="ansi-blue-fg">(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)</span>
# <span class="ansi-green-intense-fg ansi-bold">    587</span>         )
# <span class="ansi-green-intense-fg ansi-bold">    588</span>
# <span class="ansi-green-fg">--&gt; 589</span><span class="ansi-red-fg">     pandas_sql.to_sql(
# </span><span class="ansi-green-intense-fg ansi-bold">    590</span>         frame<span class="ansi-blue-fg">,</span>
# <span class="ansi-green-intense-fg ansi-bold">    591</span>         name<span class="ansi-blue-fg">,</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/pandas/io/sql.py</span> in <span class="ansi-cyan-fg">to_sql</span><span class="ansi-blue-fg">(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1825</span>             dtype<span class="ansi-blue-fg">=</span>dtype<span class="ansi-blue-fg">,</span>
# <span class="ansi-green-intense-fg ansi-bold">   1826</span>         )
# <span class="ansi-green-fg">-&gt; 1827</span><span class="ansi-red-fg">         </span>table<span class="ansi-blue-fg">.</span>create<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1828</span>         table<span class="ansi-blue-fg">.</span>insert<span class="ansi-blue-fg">(</span>chunksize<span class="ansi-blue-fg">,</span> method<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1829</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/pandas/io/sql.py</span> in <span class="ansi-cyan-fg">create</span><span class="ansi-blue-fg">(self)</span>
# <span class="ansi-green-intense-fg ansi-bold">    721</span>         <span class="ansi-green-fg">if</span> self<span class="ansi-blue-fg">.</span>exists<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    722</span>             <span class="ansi-green-fg">if</span> self<span class="ansi-blue-fg">.</span>if_exists <span class="ansi-blue-fg">==</span> <span class="ansi-blue-fg">&#34;fail&#34;</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">--&gt; 723</span><span class="ansi-red-fg">                 </span><span class="ansi-green-fg">raise</span> ValueError<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">f&#34;Table &#39;{self.name}&#39; already exists.&#34;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    724</span>             <span class="ansi-green-fg">elif</span> self<span class="ansi-blue-fg">.</span>if_exists <span class="ansi-blue-fg">==</span> <span class="ansi-blue-fg">&#34;replace&#34;</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    725</span>                 self<span class="ansi-blue-fg">.</span>pd_sql<span class="ansi-blue-fg">.</span>drop_table<span class="ansi-blue-fg">(</span>self<span class="ansi-blue-fg">.</span>name<span class="ansi-blue-fg">,</span> self<span class="ansi-blue-fg">.</span>schema<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">ValueError</span>: Table &#39;Entire_dataset_table&#39; already exists.</div>

# %% [markdown]
# Creating class Database with methods to execute our queries from section-2

# %%
class Database:

    def __init__(self, db_name='Entire_IPL_Data',):
        self.name = db_name
        self.conn = sqlt.connect('Entire_dataset_table.db')
        
        try:
          self.entire = Entire_IPL_Data.to_sql('Entire_dataset_table', conn)
        except:
          pass  
        
    def get_status(self): # To get the status of Sqlite database connection
      return self.conn    
    
    def Query_A(self):
      x = sqlContext.sql('select batting_team,match_id,bowling_team,SUM(extra_runs) AS Total_Extra_Runs \
      FROM Entire_dataset_table GROUP BY match_id,bowling_team,batting_team \
      ORDER BY SUM(extra_runs) DESC Limit 1')
      
      dict1 = {} # Creating a Dictionary python object
      
      x = x.toPandas()
  
      for column in x.columns:
         dict1[column] = x[column].values.tolist() # Traverse through each column
      return dict1
    
    def Query_B(self):
      x = sqlContext.sql('select bowler_name,SUM(is_wicket)AS Total_wickets FROM Entire_dataset_table \
      where Not dismissal_kind = "run out" "obstructing the field" \
      GROUP BY bowler_name ORDER BY SUM(is_wicket) DESC Limit 1')
      
      dict1 = {} # Creating a Dictionary python object
      
      x = x.toPandas()
  
      for column in x.columns:
         dict1[column] = x[column].values.tolist()
        
      return dict1
       
    def Query_C(self):
      x = sqlContext.sql(' select current_batsman As Player_name,SUM(batsman_runs) AS Total_runs FROM Entire_dataset_table \
      where Dl_method_used = 1 GROUP BY current_batsman ORDER BY SUM(batsman_runs) DESC limit 3')
      
      dict1 = {}
      x = x.toPandas()
      for column in x.columns:
         dict1[column] = x[column].values.tolist() # Traverse through each column
          
      return  dict1
    
    def Query_D(self):
      
      x = sqlContext.sql('select  current_batsman AS Player_name , Round((sum(batsman_runs)/count(batsman_runs))*100,2) as Strike_rate \
      from Entire_dataset_table where current_over between 1 and 6 AND  extras_type = "NA" \
      GROUP BY current_batsman ORDER BY Strike_rate DESC Limit 1')
      
      dict1 = {} # Creating a Dictionary python object
      
      x = x.toPandas()
    
      for column in x.columns:
         dict1[column] = x[column].values.tolist()
      
      return dict1
    
    def Query_E(self):
      x = sqlContext.sql(' select city_name,stadium_name,SUM(extra_runs) AS Total_Extra_runs \
      FROM Entire_dataset_table GROUP BY stadium_name,city_name ORDER BY SUM(extra_runs) DESC Limit 1')
      
      dict1 = {} # Creating a Dictionary python object
      
      x = x.toPandas()
  
      for column in x.columns:
         dict1[column] = x[column].values.tolist()
        
      return dict1
         
    def Query_F(self):
      x = sqlContext.sql('select player_of_match AS Player_name, COUNT(player_of_match) AS MOM_Awards from venue_summary_table \
      where neutral_venue = true GROUP BY player_of_match ORDER BY COUNT(player_of_match)  DESC Limit 5')
     
      x = x.select("*").toPandas()
      result = dict(x.values)
      return result       
      
    def Query_G(self):
      x = sqlContext.sql('select  current_batsman AS Player_name , Round((sum(batsman_runs)/ sum(is_wicket)), 2 ) as Batting_average \
      from Entire_dataset_table GROUP BY current_batsman ORDER BY Batting_average DESC Limit 10')
      
      x = x.select("*").toPandas()
      result = dict(x.values)
      return result
        
    def Query_H(self):
      x = sqlContext.sql('select umpire1_name, Count(umpire1_name) as Total_matches from umpire_name_union_table GROUP BY umpire1_name \
      ORDER BY COUNT(umpire1_name) DESC Limit 1')
      
      dict1 = {} # Creating a Dictionary python object
      
      x = x.toPandas()
  
      for column in x.columns:
         dict1[column] = x[column].values.tolist()
        
      return dict1
    
    
    def Query_I(self):
      x = sqlContext.sql(' select stadium_name,city_name,SUM(batsman_runs) As Total_Runs FROM Entire_dataset_table \
      where current_batsman = "V Kohli" GROUP BY stadium_name,city_name ORDER BY SUM(batsman_runs) DESC limit 1')
      
      dict1 = {} # Creating a Dictionary python object
      
      x = x.toPandas()
  
      for column in x.columns:
         dict1[column] = x[column].values.tolist()
        
      return dict1
                 
    def __del__(self):
        self.conn.close()
        
Db = Database() # Object of class Database to implement SQL queires using class methods
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Running the Status method of class Databse to check database connectivity

# %%
Db.get_status()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[99]: &lt;sqlite3.Connection at 0x7f894f108120&gt;</div>

# %% [markdown]
# 1) QUERY-A : Object to run SQl query to find the highest extra runs given by a team in a match.

# %%
Highest_Extras = Db.Query_A()
print(Highest_Extras)
print(type(Highest_Extras)) # To confirm the output is in Dictionary format or not
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#39;batting_team&#39;: [&#39;Kolkata Knight Riders&#39;], &#39;match_id&#39;: [335986], &#39;bowling_team&#39;: [&#39;Deccan Chargers&#39;], &#39;Total_Extra_Runs&#39;: [28]}
# &lt;class &#39;dict&#39;&gt;
# </div>

# %% [markdown]
# 2) QUERY-B : Object to find the Leading wicket taker in the IPL?

# %%
Highest_Wicketaker = Db.Query_B()
print(Highest_Wicketaker)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#39;bowler_name&#39;: [&#39;SL Malinga&#39;], &#39;Total_wickets&#39;: [188]}
# </div>

# %% [markdown]
# 3) QUERY-C : Object to return a report for highest run scorer in matches which were
# affected by Duckworth-Lewis’s method (D/L method).
#
# This Queries return top 5 player who have most runs in D/L affected Matches

# %%
Highest_run_DL = Db.Query_C()
print(Highest_run_DL)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#39;Player_name&#39;: [&#39;CH Gayle&#39;, &#39;DA Warner&#39;, &#39;V Kohli&#39;], &#39;Total_runs&#39;: [252, 192, 172]}
# </div>

# %% [markdown]
# 4) QUERY-D :  Object to return a report for highest strike rate by a batsman in
# powerplay (1-6 overs) excluding leg byes

# %%
Highest_strike_rate = Db.Query_D()
print(Highest_strike_rate)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#39;Player_name&#39;: [&#39;CH Morris&#39;], &#39;Strike_rate&#39;: [271.43]}
# </div>

# %% [markdown]
# 5) QUERY-E : Object to to return a report for highest extra runs in a venue (stadium,
# city)

# %%
Highest_extras_venue = Db.Query_E()
print(Highest_extras_venue)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#39;city_name&#39;: [&#39;Bengaluru&#39;], &#39;stadium_name&#39;: [&#39;M.Chinnaswamy Stadium&#39;], &#39;Total_Extra_runs&#39;: [1355]}
# </div>

# %% [markdown]
# 6) QUERY-F : Object to run SQl query to  return a report for the cricketers with the most number of
# players of the match award in neutral venues.

# %%
Most_MOM_awards = Db.Query_F()
print(Most_MOM_awards)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#39;YK Pathan&#39;: 3, &#39;GJ Maxwell&#39;: 3, &#39;JH Kallis&#39;: 3, &#39;JP Duminy&#39;: 3, &#39;KC Sangakkara&#39;: 2}
# </div>

# %% [markdown]
# 7) QUERY-G : Object to get a list of top 10 players with the highest batting average

# %%
highest_batting_avg = Db.Query_G()
print(highest_batting_avg)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#39;Iqbal Abdulla&#39;: 88.0, &#39;RD Gaikwad&#39;: 68.0, &#39;MN van Wyk&#39;: 55.67, &#39;PD Collingwood&#39;: 50.75, &#39;HM Amla&#39;: 44.38, &#39;LH Ferguson&#39;: 44.0, &#39;KL Rahul&#39;: 42.69, &#39;AB de Villiers&#39;: 42.54, &#39;DA Warner&#39;: 41.7, &#39;JP Duminy&#39;: 41.41}
# </div>

# %% [markdown]
# 8) QUERY-H : Object to find out who has officiated (as an umpire) the most number of
# matches in IPL

# %%
Most_Umpired_official = Db.Query_H()
print(Most_Umpired_official)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#39;umpire1_name&#39;: [&#39;S Ravi&#39;], &#39;Total_matches&#39;: [121]}
# </div>

# %% [markdown]
# 9) QUERY-I : Object to Find venue details of the match where V Kohli scored his highest individual runs
# in IPL

# %%
Kohli_best_score = Db.Query_I()
print(Kohli_best_score)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#39;stadium_name&#39;: [&#39;M.Chinnaswamy Stadium&#39;], &#39;city_name&#39;: [&#39;Bengaluru&#39;], &#39;Total_Runs&#39;: [2346]}
# </div>
